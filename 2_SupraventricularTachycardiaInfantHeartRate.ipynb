# %%
# Supraventricular tachycardia infant heart rate
#import packages
#import packages
# !pip install heartpy

import heartpy as hp
import matplotlib.pyplot as plt

sample_rate = 250
# Out:
# Requirement already satisfied: heartpy in c:\users\ikbel\anaconda3\lib\site-packages (1.2.7)
# Requirement already satisfied: numpy>=1.17 in c:\users\ikbel\anaconda3\lib\site-packages (from heartpy) (1.24.3)
# Requirement already satisfied: scipy in c:\users\ikbel\anaconda3\lib\site-packages (from heartpy) (1.10.1)
# Requirement already satisfied: matplotlib in c:\users\ikbel\anaconda3\lib\site-packages (from heartpy) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ikbel\anaconda3\lib\site-packages (from matplotlib->heartpy) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\ikbel\anaconda3\lib\site-packages (from matplotlib->heartpy) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ikbel\anaconda3\lib\site-packages (from matplotlib->heartpy) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ikbel\anaconda3\lib\site-packages (from matplotlib->heartpy) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ikbel\anaconda3\lib\site-packages (from matplotlib->heartpy) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ikbel\anaconda3\lib\site-packages (from matplotlib->heartpy) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ikbel\anaconda3\lib\site-packages (from matplotlib->heartpy) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ikbel\anaconda3\lib\site-packages (from matplotlib->heartpy) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\ikbel\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->heartpy) (1.16.0)

# %%
data = hp.get_data('1_Output_mono.csv')
#data = hp.get_data('data.csv')

plt.figure(figsize=(12,4))
plt.plot(data)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data = hp.get_data('1_Output_mono.csv')
#       2 #data = hp.get_data('data.csv')
#       4 plt.figure(figsize=(12,4))
#
# File ~\anaconda3\Lib\site-packages\heartpy\datautils.py:113, in get_data(filename, delim, column_name, encoding, ignore_extension)
#     109                 raise LookupError('\nError loading column "%s" from file "%s". \
#     110 Is column name specified correctly?\n The following error was provided: %s'
#     111                                  %(column_name, filename, error))
#     112         elif column_name == 'None':
# --> 113             hrdata = np.genfromtxt(filename, delimiter=delim, dtype=np.float64)
#     114         else: # pragma: no cover
#     115             raise LookupError('\nError: column name "%s" not found in header of "%s".\n'
#     116                               %(column_name, filename))
#
# File ~\anaconda3\Lib\site-packages\numpy\lib\npyio.py:1977, in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding, ndmin, like)
#    1975     fname = os_fspath(fname)
#    1976 if isinstance(fname, str):
# -> 1977     fid = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1978     fid_ctx = contextlib.closing(fid)
#    1979 else:
#
# File ~\anaconda3\Lib\site-packages\numpy\lib\_datasource.py:193, in open(path, mode, destpath, encoding, newline)
#     156 """
#     157 Open `path` with `mode` and return the file object.
#     158
#    (...)
#     189
#     190 """
#     192 ds = DataSource(destpath)
# --> 193 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File ~\anaconda3\Lib\site-packages\numpy\lib\_datasource.py:533, in DataSource.open(self, path, mode, encoding, newline)
#     530     return _file_openers[ext](found, mode=mode,
#     531                               encoding=encoding, newline=newline)
#     532 else:
# --> 533     raise FileNotFoundError(f"{path} not found.")
#
# FileNotFoundError: 1_Output_mono.csv not found.

# %%
#run analysis
wd, m = hp.process(data, sample_rate)

#visualise in plot of custom size
plt.figure(figsize=(12,4))
hp.plotter(wd, m)

#display computed measures
for measure in m.keys():
    print('%s: %f' %(measure, m[measure]))
# Out:
# bpm: 91.886486
# ibi: 652.979592
# sdnn: 171.671315
# sdsd: 129.442489
# rmssd: 178.945057
# pnn20: 0.888889
# pnn50: 0.555556
# hr_mad: 148.000000
# sd1: 115.278300
# sd2: 244.919942
# s: 88699.583935
# sd1/sd2: 0.470677
# breathingrate: 0.266667
# C:\Users\ikbel\anaconda3\Lib\site-packages\heartpy\visualizeutils.py:119: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
